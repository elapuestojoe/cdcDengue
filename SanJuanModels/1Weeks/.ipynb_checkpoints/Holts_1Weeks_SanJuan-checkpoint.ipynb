# %%
import statsmodels.api as sm
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sanjuan_dataset = pd.read_csv("../../dengueData/SanJuan/san_juan_training_data.csv")
print(sanjuan_dataset.head())
print("Number of observations: ", len(sanjuan_dataset))
# Out:
#       season  season_week week_start_date  denv1_cases  denv2_cases  \
# 0  1990/1991            1      1990-04-30            0            0
# 1  1990/1991            2      1990-05-07            0            0
# 2  1990/1991            3      1990-05-14            0            0
# 3  1990/1991            4      1990-05-21            0            0
# 4  1990/1991            5      1990-05-28            0            0
#
#    denv3_cases  denv4_cases  other_positive_cases  additional_cases  \
# 0            0            0                     4                 0
# 1            0            0                     5                 0
# 2            0            0                     4                 0
# 3            0            0                     3                 0
# 4            0            0                     6                 0
#
#    total_cases
# 0            4
# 1            5
# 2            4
# 3            3
# 4            6
# Number of observations:  988

# %%
sanjuan_cases = sanjuan_dataset["total_cases"].values
print(sanjuan_cases.shape)
# Out:
# (988,)

# %%
sm.tsa.seasonal_decompose(sanjuan_cases, freq = 52).plot()
# result = sm.tsa.stattools.adfuller(sanjuan_cases)
# print(result)
print("")

# %%
split_index = int(len(sanjuan_cases)* 0.7)
window_size = 4
future_steps = 1
train = sanjuan_cases[:split_index+window_size]

#Test goes from train to end - future_steps (as this data will be feed into the model)
#Expected is always future_steps ahead of test as this is the expected predictions
test = sanjuan_cases[split_index+window_size-future_steps:-future_steps]
expected = sanjuan_cases[split_index+window_size:]

print(test[-5:])
print(expected[-5:])
print(train.shape)
print(test.shape)
print(expected.shape)
print(sanjuan_cases[-5:])
# Out:
# [26 24  9 21 10]
# [24  9 21 10 15]
# (695,)
# (293,)
# (293,)
# [24  9 21 10 15]

# %%
from statsmodels.tsa.api import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import time
from statsmodels.tsa.statespace.sarimax import SARIMAX
history = [x for x in train]
predictions = list()
start = time.time()
for t in range(len(test)):
    model = ExponentialSmoothing(np.asarray(history) ,seasonal_periods=int(len(history)/52) ,trend='add', seasonal='add',)
    
    model_fit = model.fit()
    output = model_fit.forecast(steps=future_steps)
    yhat = output[0]
    predictions.append(yhat)
    obs = expected[t]
    history.append(test[t])
    print('predicted=%f, expected=%f' % (yhat, obs))

end = time.time()
print("Total time: ", end-start)
error = mean_squared_error(expected, predictions)
print('Test MSE: %.3f' % error)
# plot
plt.plot(expected)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=27.378687, expected=35.000000
# predicted=22.529854, expected=28.000000
# predicted=37.995242, expected=37.000000
# predicted=32.075003, expected=41.000000
# predicted=40.061700, expected=34.000000
# predicted=40.999624, expected=30.000000
# predicted=35.661543, expected=39.000000
# predicted=32.856733, expected=39.000000
# predicted=40.237519, expected=39.000000
# predicted=37.795545, expected=34.000000
# predicted=37.957727, expected=30.000000
# predicted=31.455923, expected=37.000000
# predicted=31.283533, expected=29.000000
# predicted=38.063051, expected=26.000000
# predicted=26.331541, expected=15.000000
# predicted=27.507186, expected=22.000000
# predicted=18.889171, expected=15.000000
# predicted=23.761647, expected=20.000000
# predicted=13.430727, expected=14.000000
# predicted=20.064000, expected=10.000000
# predicted=16.533632, expected=21.000000
# predicted=9.913026, expected=14.000000
# predicted=18.298661, expected=14.000000
# predicted=11.711649, expected=9.000000
# predicted=10.301369, expected=11.000000
# predicted=9.687523, expected=5.000000
# predicted=10.311449, expected=6.000000
# predicted=1.561274, expected=7.000000
# predicted=5.813980, expected=11.000000
# predicted=10.875247, expected=4.000000
# predicted=12.020193, expected=3.000000
# predicted=2.961764, expected=2.000000
# predicted=2.187886, expected=6.000000
# predicted=-4.263976, expected=10.000000
# predicted=4.630642, expected=7.000000
# predicted=9.767008, expected=5.000000
# predicted=5.808764, expected=3.000000
# predicted=6.925649, expected=12.000000
# predicted=4.807684, expected=13.000000
# predicted=12.329038, expected=10.000000
# predicted=11.234927, expected=13.000000
# predicted=9.799612, expected=13.000000
# predicted=13.793161, expected=8.000000
# predicted=13.802463, expected=21.000000
# predicted=7.119208, expected=18.000000
# predicted=22.867802, expected=8.000000
# predicted=18.410616, expected=7.000000
# predicted=3.310878, expected=20.000000
# predicted=5.877327, expected=14.000000
# predicted=19.474781, expected=14.000000
# predicted=13.503672, expected=7.000000
# predicted=16.210605, expected=14.000000
# predicted=9.931338, expected=10.000000
# predicted=14.265735, expected=13.000000
# predicted=8.267374, expected=27.000000
# predicted=12.896805, expected=13.000000
# predicted=27.728619, expected=18.000000
# predicted=14.273850, expected=16.000000
# predicted=18.134024, expected=16.000000
# predicted=17.394378, expected=20.000000
# predicted=15.798882, expected=17.000000
# predicted=15.900615, expected=4.000000
# predicted=17.041001, expected=15.000000
# predicted=2.963130, expected=8.000000
# predicted=13.871622, expected=6.000000
# predicted=9.689102, expected=12.000000
# predicted=9.287035, expected=15.000000
# predicted=11.794673, expected=11.000000
# predicted=13.627793, expected=10.000000
# predicted=11.673235, expected=15.000000
# predicted=9.131656, expected=17.000000
# predicted=16.291617, expected=7.000000
# predicted=16.960145, expected=7.000000
# predicted=8.426747, expected=8.000000
# predicted=6.680959, expected=9.000000
# predicted=3.331203, expected=12.000000
# predicted=7.727491, expected=12.000000
# predicted=11.906748, expected=5.000000
# predicted=10.474289, expected=4.000000
# predicted=6.719576, expected=11.000000
# predicted=7.569782, expected=4.000000
# predicted=10.826562, expected=5.000000
# predicted=2.392156, expected=7.000000
# predicted=5.261040, expected=1.000000
# predicted=6.325740, expected=1.000000
# predicted=0.776706, expected=4.000000
# predicted=-3.645543, expected=2.000000
# predicted=5.177468, expected=6.000000
# predicted=2.156631, expected=3.000000
# predicted=8.888790, expected=4.000000
# predicted=-0.163970, expected=10.000000
# predicted=2.683252, expected=12.000000
# predicted=11.010853, expected=21.000000
# predicted=14.770253, expected=26.000000
# predicted=21.319984, expected=21.000000
# predicted=26.620330, expected=30.000000
# predicted=20.189106, expected=45.000000
# predicted=28.906458, expected=56.000000
# predicted=45.520890, expected=75.000000
# predicted=59.618054, expected=83.000000
# predicted=77.498722, expected=82.000000
# predicted=82.215372, expected=126.000000
# predicted=86.342738, expected=119.000000
# predicted=129.735979, expected=137.000000
# predicted=126.839930, expected=131.000000
# predicted=139.023090, expected=112.000000
# predicted=135.374604, expected=82.000000
# predicted=117.641088, expected=73.000000
# predicted=88.518506, expected=43.000000
# predicted=74.907037, expected=55.000000
# predicted=43.775008, expected=55.000000
# predicted=53.832985, expected=53.000000
# predicted=54.012078, expected=46.000000
# predicted=52.602969, expected=43.000000
# predicted=48.428328, expected=29.000000
# predicted=42.723691, expected=22.000000
# predicted=24.662615, expected=26.000000
# predicted=24.232958, expected=13.000000
# predicted=22.842985, expected=17.000000
# predicted=15.683192, expected=8.000000
# predicted=11.817365, expected=13.000000
# predicted=4.768035, expected=10.000000
# predicted=11.285777, expected=17.000000
# predicted=12.418966, expected=19.000000
# predicted=14.645784, expected=9.000000
# predicted=19.631209, expected=9.000000
# predicted=6.832831, expected=9.000000
# predicted=6.261006, expected=3.000000
# predicted=6.692276, expected=7.000000
# predicted=4.037673, expected=7.000000
# predicted=4.957160, expected=0.000000
# predicted=2.316530, expected=2.000000
# predicted=2.358463, expected=3.000000
# predicted=-1.852498, expected=3.000000
# predicted=6.049322, expected=1.000000
# predicted=-1.886857, expected=3.000000
# predicted=-1.271191, expected=3.000000
# predicted=-2.339770, expected=3.000000
# predicted=-1.929685, expected=7.000000
# predicted=0.822557, expected=3.000000
# predicted=6.786646, expected=5.000000
# predicted=0.052488, expected=11.000000
# predicted=4.792057, expected=5.000000
# predicted=12.314985, expected=5.000000
# predicted=7.298339, expected=6.000000
# predicted=3.847235, expected=6.000000
# predicted=5.697540, expected=4.000000
# predicted=3.145661, expected=4.000000
# predicted=3.047246, expected=8.000000
# predicted=5.387701, expected=14.000000
# predicted=12.567190, expected=12.000000
# predicted=16.835047, expected=16.000000
# predicted=10.682094, expected=10.000000
# predicted=11.792476, expected=16.000000
# predicted=6.204527, expected=18.000000
# predicted=14.664718, expected=15.000000
# predicted=18.296759, expected=23.000000
# predicted=13.387926, expected=17.000000
# predicted=23.736743, expected=33.000000
# predicted=18.740683, expected=15.000000
# predicted=35.970876, expected=13.000000
# predicted=15.661622, expected=11.000000
# predicted=13.226434, expected=14.000000
# predicted=8.575405, expected=17.000000
# predicted=13.323724, expected=19.000000
# predicted=18.975222, expected=20.000000
# predicted=24.139264, expected=12.000000
# predicted=23.009225, expected=21.000000
# predicted=11.452110, expected=7.000000
# predicted=16.345358, expected=19.000000
# predicted=3.999203, expected=10.000000
# predicted=17.115810, expected=13.000000
# predicted=10.036731, expected=10.000000
# predicted=11.591638, expected=8.000000
# predicted=9.740717, expected=21.000000
# predicted=10.091354, expected=11.000000
# predicted=21.617153, expected=9.000000
# predicted=11.925379, expected=14.000000
# predicted=9.108744, expected=14.000000
# predicted=11.820636, expected=15.000000
# predicted=13.450939, expected=18.000000
# predicted=16.819269, expected=16.000000
# predicted=22.825178, expected=12.000000
# predicted=18.615046, expected=20.000000
# predicted=12.362276, expected=8.000000
# predicted=14.430593, expected=3.000000
# predicted=6.261593, expected=13.000000
# predicted=0.133107, expected=4.000000
# predicted=12.749873, expected=1.000000
# predicted=5.156495, expected=10.000000
# predicted=-1.489375, expected=8.000000
# predicted=6.737668, expected=13.000000
# predicted=3.791573, expected=10.000000
# predicted=13.380351, expected=21.000000
# predicted=9.919732, expected=18.000000
# predicted=24.462221, expected=21.000000
# predicted=15.935587, expected=34.000000
# predicted=19.776791, expected=25.000000
# predicted=34.308129, expected=34.000000
# predicted=27.172902, expected=33.000000
# predicted=34.309910, expected=40.000000
# predicted=38.239684, expected=42.000000
# predicted=41.391271, expected=36.000000
# predicted=41.611645, expected=72.000000
# predicted=41.392159, expected=75.000000
# predicted=71.435383, expected=76.000000
# predicted=78.939213, expected=92.000000
# predicted=77.511928, expected=71.000000
# predicted=91.432801, expected=112.000000
# predicted=70.646058, expected=106.000000
# predicted=113.953891, expected=101.000000
# predicted=110.595619, expected=170.000000
# predicted=107.250963, expected=135.000000
# predicted=171.015958, expected=106.000000
# predicted=140.411598, expected=68.000000
# predicted=109.165932, expected=48.000000
# predicted=72.692964, expected=48.000000
# predicted=48.045367, expected=26.000000
# predicted=51.997282, expected=33.000000
# predicted=26.114478, expected=29.000000
# predicted=29.637725, expected=17.000000
# predicted=33.977474, expected=12.000000
# predicted=13.037904, expected=13.000000
# predicted=11.152237, expected=17.000000
# predicted=10.774460, expected=15.000000
# predicted=10.257694, expected=14.000000
# predicted=13.112761, expected=15.000000
# predicted=10.011698, expected=10.000000
# predicted=14.024778, expected=9.000000
# predicted=15.194829, expected=2.000000
# predicted=0.295111, expected=6.000000
# predicted=-0.813885, expected=8.000000
# predicted=2.344315, expected=5.000000
# predicted=9.128719, expected=1.000000
# predicted=4.303477, expected=2.000000
# predicted=2.665352, expected=3.000000
# predicted=2.637781, expected=4.000000
# predicted=-0.641263, expected=3.000000
# predicted=7.867784, expected=1.000000
# predicted=-0.114198, expected=3.000000
# predicted=0.965040, expected=5.000000
# predicted=-2.919612, expected=2.000000
# predicted=0.995115, expected=3.000000
# predicted=-0.254084, expected=2.000000
# predicted=-0.447872, expected=3.000000
# predicted=2.467510, expected=2.000000
# predicted=-0.023065, expected=2.000000
# predicted=-1.011818, expected=3.000000
# predicted=2.069647, expected=4.000000
# predicted=-3.626806, expected=3.000000
# predicted=3.080125, expected=4.000000

# %%
from statsmodels.tsa.api import ExponentialSmoothing
from sklearn.metrics import mean_squared_error

fit1 = ExponentialSmoothing(np.asarray(train) ,seasonal_periods=int(len(train)/52) ,trend='add', seasonal='add',).fit()
predictions = fit1.forecast(len(test))

error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# Test MSE: 17272.768
