# %%
import statsmodels.api as sm
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sanjuan_dataset = pd.read_csv("../../dengueData/SanJuan/san_juan_training_data.csv")
print(sanjuan_dataset.head())
print("Number of observations: ", len(sanjuan_dataset))
# Out:
#       season  season_week week_start_date  denv1_cases  denv2_cases  \
# 0  1990/1991            1      1990-04-30            0            0
# 1  1990/1991            2      1990-05-07            0            0
# 2  1990/1991            3      1990-05-14            0            0
# 3  1990/1991            4      1990-05-21            0            0
# 4  1990/1991            5      1990-05-28            0            0
#
#    denv3_cases  denv4_cases  other_positive_cases  additional_cases  \
# 0            0            0                     4                 0
# 1            0            0                     5                 0
# 2            0            0                     4                 0
# 3            0            0                     3                 0
# 4            0            0                     6                 0
#
#    total_cases
# 0            4
# 1            5
# 2            4
# 3            3
# 4            6
# Number of observations:  988

# %%
sanjuan_cases = sanjuan_dataset["total_cases"].values
print(sanjuan_cases.shape)
# Out:
# (988,)

# %%
sm.tsa.seasonal_decompose(sanjuan_cases, freq = 52).plot()
# result = sm.tsa.stattools.adfuller(sanjuan_cases)
# print(result)
print("")

# %%
split_index = int(len(sanjuan_cases)* 0.7)
future_steps = 2
window_size = 4
train = sanjuan_cases[:split_index]

#Test goes from train to end - future_steps (as this data will be feed into the model)
#Expected is always future_steps ahead of test as this is the expected predictions
test = sanjuan_cases[split_index+window_size-1:-future_steps]
expected = sanjuan_cases[split_index+future_steps+window_size-1:]

print(test[-5:])
print(expected[-5:])
print(train.shape)
print(test.shape)
print(expected.shape)
print(sanjuan_cases[-5:])
# Out:
# [22 26 24  9 21]
# [24  9 21 10 15]
# (691,)
# (292,)
# (292,)
# [24  9 21 10 15]

# %%
from statsmodels.tsa.api import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import time
from statsmodels.tsa.statespace.sarimax import SARIMAX
history = [x for x in train]
predictions = list()
start = time.time()
for t in range(len(test)):
    model = ExponentialSmoothing(np.asarray(history) ,seasonal_periods=int(len(history)/52) ,trend='add', seasonal='add',)
    
    model_fit = model.fit()
    output = model_fit.forecast(steps=future_steps)
    yhat = output[0]
    predictions.append(yhat)
    obs = expected[t]
    history.append(test[t])
    print('predicted=%f, expected=%f' % (yhat, obs))

end = time.time()
print("Total time: ", end-start)
# Out:
# predicted=23.659106, expected=28.000000
# predicted=23.971749, expected=37.000000
# predicted=32.719605, expected=41.000000
# predicted=30.514486, expected=34.000000
# predicted=38.129416, expected=30.000000
# predicted=38.038494, expected=39.000000
# predicted=37.749520, expected=39.000000
# predicted=33.964568, expected=39.000000
# predicted=42.079467, expected=34.000000
# predicted=39.040753, expected=30.000000
# predicted=40.483298, expected=37.000000
# predicted=37.043747, expected=29.000000
# predicted=31.409368, expected=26.000000
# predicted=35.536444, expected=15.000000
# predicted=27.505413, expected=22.000000
# predicted=22.536483, expected=15.000000
# predicted=17.103589, expected=20.000000
# predicted=21.793609, expected=14.000000
# predicted=10.461292, expected=10.000000
# predicted=21.805856, expected=21.000000
# predicted=17.596979, expected=14.000000
# predicted=11.630386, expected=14.000000
# predicted=19.489209, expected=9.000000
# predicted=14.095421, expected=11.000000
# predicted=15.666686, expected=5.000000
# predicted=10.058195, expected=6.000000
# predicted=7.906775, expected=7.000000
# predicted=2.525244, expected=11.000000
# predicted=1.156177, expected=4.000000
# predicted=8.923029, expected=3.000000
# predicted=10.039111, expected=2.000000
# predicted=0.015549, expected=6.000000
# predicted=3.632724, expected=10.000000
# predicted=4.991849, expected=7.000000
# predicted=8.215158, expected=5.000000
# predicted=7.861169, expected=3.000000
# predicted=7.118601, expected=12.000000
# predicted=0.456187, expected=13.000000
# predicted=1.234040, expected=10.000000
# predicted=10.568894, expected=13.000000
# predicted=13.455724, expected=13.000000
# predicted=11.745385, expected=8.000000
# predicted=16.059756, expected=21.000000
# predicted=13.062057, expected=18.000000
# predicted=6.102960, expected=8.000000
# predicted=21.655389, expected=7.000000
# predicted=19.414244, expected=20.000000
# predicted=8.056166, expected=14.000000
# predicted=6.383780, expected=14.000000
# predicted=22.540598, expected=7.000000
# predicted=12.814816, expected=14.000000
# predicted=10.058141, expected=10.000000
# predicted=6.213235, expected=13.000000
# predicted=12.384105, expected=27.000000
# predicted=10.244649, expected=13.000000
# predicted=14.825007, expected=18.000000
# predicted=29.967641, expected=16.000000
# predicted=13.692205, expected=16.000000
# predicted=17.139255, expected=20.000000
# predicted=16.183217, expected=17.000000
# predicted=16.662902, expected=4.000000
# predicted=20.416231, expected=15.000000
# predicted=17.747616, expected=8.000000
# predicted=5.899111, expected=6.000000
# predicted=13.391550, expected=12.000000
# predicted=3.853681, expected=15.000000
# predicted=5.456393, expected=11.000000
# predicted=9.799156, expected=10.000000
# predicted=15.375583, expected=15.000000
# predicted=13.578389, expected=17.000000
# predicted=11.346764, expected=7.000000
# predicted=15.862986, expected=7.000000
# predicted=15.997173, expected=8.000000
# predicted=7.223068, expected=9.000000
# predicted=7.418273, expected=12.000000
# predicted=7.627847, expected=12.000000
# predicted=8.615775, expected=5.000000
# predicted=14.730615, expected=4.000000
# predicted=10.187041, expected=11.000000
# predicted=1.196648, expected=4.000000
# predicted=3.652358, expected=5.000000
# predicted=8.722530, expected=7.000000
# predicted=3.920841, expected=1.000000
# predicted=7.135479, expected=1.000000
# predicted=8.519242, expected=4.000000
# predicted=1.723261, expected=2.000000
# predicted=-1.122304, expected=6.000000
# predicted=3.978106, expected=3.000000
# predicted=2.499860, expected=4.000000
# predicted=6.022517, expected=10.000000
# predicted=-0.746115, expected=12.000000
# predicted=4.558049, expected=21.000000
# predicted=9.629855, expected=26.000000
# predicted=17.184881, expected=21.000000
# predicted=17.665566, expected=30.000000
# predicted=24.897291, expected=45.000000
# predicted=24.313384, expected=56.000000
# predicted=31.514783, expected=75.000000
# predicted=47.409179, expected=83.000000
# predicted=57.224307, expected=82.000000
# predicted=76.388277, expected=126.000000
# predicted=82.166719, expected=119.000000
# predicted=85.471564, expected=137.000000
# predicted=131.388512, expected=131.000000
# predicted=124.210672, expected=112.000000
# predicted=138.319385, expected=82.000000
# predicted=137.104251, expected=73.000000
# predicted=116.432012, expected=43.000000
# predicted=90.754363, expected=55.000000
# predicted=71.585756, expected=55.000000
# predicted=41.964249, expected=53.000000
# predicted=57.633922, expected=46.000000
# predicted=56.689069, expected=43.000000
# predicted=54.534587, expected=29.000000
# predicted=46.252620, expected=22.000000
# predicted=41.541406, expected=26.000000
# predicted=24.552661, expected=13.000000
# predicted=23.412713, expected=17.000000
# predicted=24.366484, expected=8.000000
# predicted=13.276474, expected=13.000000
# predicted=11.009548, expected=10.000000
# predicted=6.357371, expected=17.000000
# predicted=10.232753, expected=19.000000
# predicted=14.488077, expected=9.000000
# predicted=11.621656, expected=9.000000
# predicted=17.744990, expected=9.000000
# predicted=10.313848, expected=3.000000
# predicted=8.974577, expected=7.000000
# predicted=8.671744, expected=7.000000
# predicted=2.104065, expected=0.000000
# predicted=3.753120, expected=2.000000
# predicted=2.158304, expected=3.000000
# predicted=1.569595, expected=3.000000
# predicted=-0.468431, expected=1.000000
# predicted=3.832115, expected=3.000000
# predicted=-2.787243, expected=3.000000
# predicted=0.179569, expected=3.000000
# predicted=0.556318, expected=7.000000
# predicted=8.108471, expected=3.000000
# predicted=-1.500896, expected=5.000000
# predicted=5.103485, expected=11.000000
# predicted=-4.575028, expected=5.000000
# predicted=2.464037, expected=5.000000
# predicted=9.450620, expected=6.000000
# predicted=4.908485, expected=6.000000
# predicted=3.923235, expected=4.000000
# predicted=5.915776, expected=4.000000
# predicted=6.546812, expected=8.000000
# predicted=4.754357, expected=14.000000
# predicted=3.168545, expected=12.000000
# predicted=9.165241, expected=16.000000
# predicted=11.466493, expected=10.000000
# predicted=10.173571, expected=16.000000
# predicted=17.798108, expected=18.000000
# predicted=11.877830, expected=15.000000
# predicted=19.891338, expected=23.000000
# predicted=19.575755, expected=17.000000
# predicted=9.080639, expected=33.000000
# predicted=21.316795, expected=15.000000
# predicted=15.921165, expected=13.000000
# predicted=33.570654, expected=11.000000
# predicted=15.603427, expected=14.000000
# predicted=13.419016, expected=17.000000
# predicted=11.793345, expected=19.000000
# predicted=15.114620, expected=20.000000
# predicted=16.986458, expected=12.000000
# predicted=20.834912, expected=21.000000
# predicted=17.766701, expected=7.000000
# predicted=10.686723, expected=19.000000
# predicted=21.970486, expected=10.000000
# predicted=9.643923, expected=13.000000
# predicted=22.340096, expected=10.000000
# predicted=11.516364, expected=8.000000
# predicted=7.598529, expected=21.000000
# predicted=7.250149, expected=11.000000
# predicted=7.310966, expected=9.000000
# predicted=19.209543, expected=14.000000
# predicted=11.742008, expected=14.000000
# predicted=9.272371, expected=15.000000
# predicted=14.865939, expected=18.000000
# predicted=15.312987, expected=16.000000
# predicted=15.051464, expected=12.000000
# predicted=19.622808, expected=20.000000
# predicted=13.495486, expected=8.000000
# predicted=11.359699, expected=3.000000
# predicted=19.684427, expected=13.000000
# predicted=11.861161, expected=4.000000
# predicted=5.349917, expected=1.000000
# predicted=14.417184, expected=10.000000
# predicted=-1.085778, expected=8.000000
# predicted=-2.174873, expected=13.000000
# predicted=9.614006, expected=10.000000
# predicted=5.298491, expected=21.000000
# predicted=13.530506, expected=18.000000
# predicted=7.080231, expected=21.000000
# predicted=21.208388, expected=34.000000
# predicted=15.487596, expected=25.000000
# predicted=21.494817, expected=34.000000
# predicted=35.694592, expected=33.000000
# predicted=27.299900, expected=40.000000
# predicted=31.505134, expected=42.000000
# predicted=33.862308, expected=36.000000
# predicted=40.646367, expected=72.000000
# predicted=41.835879, expected=75.000000
# predicted=42.055948, expected=76.000000
# predicted=72.886836, expected=92.000000
# predicted=79.635850, expected=71.000000
# predicted=78.647942, expected=112.000000
# predicted=94.883733, expected=106.000000
# predicted=73.882151, expected=101.000000
# predicted=114.267629, expected=170.000000
# predicted=107.933978, expected=135.000000
# predicted=104.040825, expected=106.000000
# predicted=170.432361, expected=68.000000
# predicted=142.012589, expected=48.000000
# predicted=110.568708, expected=48.000000
# predicted=72.889755, expected=26.000000
# predicted=45.400055, expected=33.000000
# predicted=47.713624, expected=29.000000
# predicted=25.188973, expected=17.000000
# predicted=29.822971, expected=12.000000
# predicted=34.632163, expected=13.000000
# predicted=14.452661, expected=17.000000
# predicted=11.875372, expected=15.000000
# predicted=11.865598, expected=14.000000
# predicted=13.556493, expected=15.000000
# predicted=16.343059, expected=10.000000
# predicted=10.478677, expected=9.000000
# predicted=11.529244, expected=2.000000
# predicted=12.019766, expected=6.000000
# predicted=-0.430325, expected=8.000000
# predicted=0.669903, expected=5.000000
# predicted=3.758691, expected=1.000000
# predicted=9.395042, expected=2.000000
# predicted=1.816444, expected=3.000000
# predicted=-1.523510, expected=4.000000
# predicted=1.541053, expected=3.000000
# predicted=-0.511629, expected=1.000000
# predicted=8.509938, expected=3.000000
# predicted=1.268328, expected=5.000000
# predicted=1.718795, expected=2.000000
# predicted=2.848044, expected=3.000000
# predicted=2.143661, expected=2.000000
# predicted=3.767964, expected=3.000000
# predicted=0.378579, expected=2.000000
# predicted=0.188922, expected=2.000000
# predicted=-1.703130, expected=3.000000
# predicted=-0.374005, expected=4.000000
# predicted=2.827357, expected=3.000000
# predicted=-3.622430, expected=4.000000
# predicted=0.659170, expected=4.000000
# predicted=-2.246651, expected=4.000000
# predicted=2.332518, expected=7.000000
# predicted=4.906104, expected=6.000000
# predicted=3.329247, expected=15.000000
# predicted=12.145945, expected=11.000000
# predicted=7.236515, expected=9.000000
# predicted=13.218974, expected=9.000000
# predicted=17.235507, expected=12.000000
# predicted=10.861395, expected=13.000000
# predicted=11.381036, expected=13.000000
# predicted=14.555715, expected=13.000000
# predicted=11.255889, expected=20.000000
# predicted=12.205519, expected=28.000000
# predicted=9.319801, expected=45.000000
# predicted=18.422421, expected=28.000000
# predicted=29.932689, expected=34.000000
# predicted=40.327673, expected=41.000000
# predicted=26.735730, expected=36.000000
# predicted=30.243604, expected=38.000000
# predicted=40.612767, expected=48.000000
# predicted=38.529274, expected=27.000000
# predicted=39.000948, expected=23.000000
# predicted=54.080104, expected=28.000000
# predicted=30.751557, expected=42.000000
# predicted=21.434237, expected=30.000000
# predicted=33.840360, expected=18.000000
# predicted=44.534388, expected=38.000000
# predicted=33.712808, expected=28.000000
# predicted=21.014505, expected=36.000000
# predicted=36.136934, expected=44.000000
# predicted=27.889410, expected=41.000000
# predicted=33.073527, expected=35.000000
# predicted=42.996861, expected=28.000000
# predicted=43.884231, expected=28.000000
# predicted=28.989426, expected=22.000000
# predicted=26.609818, expected=26.000000
# predicted=23.887147, expected=24.000000
# predicted=19.972371, expected=9.000000
# predicted=27.204027, expected=21.000000
# predicted=24.495503, expected=10.000000
# predicted=12.078076, expected=15.000000
# Total time:  2952.347929954529

# %%
error = mean_squared_error(expected, predictions)
print('Test MSE: %.3f' % error)
# plot
plt.plot(expected)
plt.plot(predictions, color='red')
plt.show()
# Out:
# Test MSE: 273.041
